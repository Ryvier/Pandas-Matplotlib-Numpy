# %%
# To import pandas
import pandas as pd
# To read csv
pd.read_csv(r"C:\Users\enzri\OneDrive\Desktop\projects\test.csv")
# Out:
#     lamp_id  1/4/2023  2/4/2023  3/4/2023  4/4/2023  5/4/2023  6/4/2023  \
# 0        99      4354      4225      2846      4222      4316      3456
# 1       100      4390      4274      1763      4036      4172      3730
# 2       109      6002      5582      6044      5404      5278      5568
# 3        73      3250      2112       349         3         0         0
# 4        74      1981      3313      4677      4595      4539      4442
# 5        88       559       508        59        52       415       392
# 6        81       398       418        53        97       426       331
# 7        90       332       110       564       391       653         3
# 8        91       354        50       579       608       652         3
# 9        92       245        90       495       429       584         1
# 10       77       170        64       339         1         0         2
# 11       14       265       463       555       155         0       564
# ...

# %%
#  To get a quick overview of the data.
df.head()
# Out:
#    lamp_id  1/4/2023  2/4/2023  3/4/2023  4/4/2023  5/4/2023  6/4/2023  \
# 0       99      4354      4225      2846      4222      4316      3456
# 1      100      4390      4274      1763      4036      4172      3730
# 2      109      6002      5582      6044      5404      5278      5568
# 3       73      3250      2112       349         3         0         0
# 4       74      1981      3313      4677      4595      4539      4442
#
#    7/4/2023  8/4/2023  9/4/2023  10/4/2023  11/4/2023  12/4/2023  13/4/2023  \
# 0      2913      3024      4387       4320       4365       4244       3916
# 1      3282      4076      4572       4892       4458       4259       4232
# 2      5610      5673      6139       6481       5587       5782       6904
# 3       267      4372      1633          4          1        332        178
# 4      4372      4515      4982       4566       2673       5188       5036
#
#    14/4/2023  15/4/2023
# 0       3524       3609
# 1       3876       3584
# ...

# %%
# To access data for a specific lamp or date, you can use DataFrame indexing. 
data = df.loc[df['lamp_id'] == 99, '1/4/2023'].values[0]
print("Data:", data)
# Out:
# Data: 4354

# %%
# To calculate basic statistics, like mean, median, and standard deviation for a specific column.
print("Mean:", mean_value)
print("Median:", median_value)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 1612.7297297297298
# Median: 800.0
# Standard Deviation: 1704.4966941829134

# %%
# Find the lamp with the highest lamp_id
highest_lamp_id = df.index.max()
print("Highest Lamp ID:", highest_lamp_id)
# Out:
# Highest Lamp ID: 117

# %%
# Find the lamp with the lowest lamp_id
lowest_lamp_id = df.index.min()
print("Lowest Lamp ID:", lowest_lamp_id)
# Out:
# Lowest Lamp ID: 7

# %%
# Access data for a specific date or lamp_id
df = pd.read_csv("test.csv", index_col='lamp_id')
lamp_id_to_access = 117
selected_row = df.loc[lamp_id_to_access]
print(selected_row)
# Out:
# 1/4/2023     2608
# 2/4/2023     2532
# 3/4/2023     3007
# 4/4/2023     2823
# 5/4/2023     3036
# 6/4/2023     2350
# 7/4/2023     1759
# 8/4/2023     2690
# 9/4/2023     2594
# 10/4/2023    2271
# 11/4/2023    2469
# 12/4/2023    2821
# 13/4/2023    2324
# 14/4/2023    2150
# 15/4/2023    2233
# Name: 117, dtype: int64

# %%
# Access data for a specific date or lamp_id
lamp_id_to_access = 7
data_for_lamp_7 = df.loc[lamp_id_to_access]
print(data_for_lamp_7)
# Out:
# 1/4/2023     426
# 2/4/2023       2
# 3/4/2023       1
# 4/4/2023       5
# 5/4/2023     498
# 6/4/2023     590
# 7/4/2023     628
# 8/4/2023     144
# 9/4/2023     602
# 10/4/2023    443
# 11/4/2023    465
# 12/4/2023    639
# 13/4/2023    640
# 14/4/2023    581
# 15/4/2023    567
# Name: 7, dtype: int64

# %%
pd.set_option('display.max_columns', None)
df_transposed = df.T
print(df_transposed)
# Out:
# lamp_id     99    100   109   73    74   88   81   90    91    92    77   \
# 1/4/2023   4354  4390  6002  3250  1981  559  398  332   354   245   170
# 2/4/2023   4225  4274  5582  2112  3313  508  418  110    50    90    64
# 3/4/2023   2846  1763  6044   349  4677   59   53  564   579   495   339
# 4/4/2023   4222  4036  5404     3  4595   52   97  391   608   429     1
# 5/4/2023   4316  4172  5278     0  4539  415  426  653   652   584     0
# 6/4/2023   3456  3730  5568     0  4442  392  331    3     3     1     2
# 7/4/2023   2913  3282  5610   267  4372  409  405    1     1     0   349
# 8/4/2023   3024  4076  5673  4372  4515    1    3  241   264   159   449
# 9/4/2023   4387  4572  6139  1633  4982    1    1   91   111   105   409
# 10/4/2023  4320  4892  6481     4  4566  369  423    6     4     4     2
# 11/4/2023  4365  4458  5587     1  2673  328  379    0     1     0     2
# 12/4/2023  4244  4259  5782   332  5188  171  175    0     0     0   370
# ...

# %%
# Sort the DataFrame by 'lamp_id' in ascending order
df_sorted = df_transposed.sort_values(by='lamp_id', axis=1, ascending=True)
# Display the sorted DataFrame
print(df_sorted)
# Out:
# lamp_id    7     14    19   20    22   23    27    34   35    36    37    38   \
# 1/4/2023   426   265  1705   88  2923  231  1785  2464    0     0     0     0
# 2/4/2023     2   463  1876  165  3041  219  1598  2403    0     0     0     0
# 3/4/2023     1   555  1988  183  3118  446  2217  2234    0     0     0     0
# 4/4/2023     5   155  1362   60  3151  738  2578  2272    0     0     0     0
# 5/4/2023   498     0   419    2  3215  658  2882  2628    0     0     0     0
# 6/4/2023   590   564  1979  180  3269  366  1947  1392    0     0     0     0
# 7/4/2023   628   463  1969  148  2807  863  2258  2136    0     2     0     2
# 8/4/2023   144   397  1702  130  2798  795  2444  2440  165   153   169   176
# 9/4/2023   602   570  2031  186  3117  767  2419  2577    1     0     0     1
# 10/4/2023  443   481  1819  151  2864  396  2267  1718  135   152   190   154
# 11/4/2023  465   390  1940  126  3147  408  2045  2413    0     0     0     0
# ...
